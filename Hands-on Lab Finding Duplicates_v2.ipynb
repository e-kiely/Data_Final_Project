# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 166.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 183.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 101.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 141.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 83.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 144.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
# Count the number of duplicate rows in the dataset.
duplicate_count = df.duplicated().sum()
print("No. of duplicate rows", duplicate_count)
#Display the first few duplicate rows to understand their structure
duplicate_rows = df[df.duplicated(keep=False)]
print(duplicate_rows.head())
# Out:
# No. of duplicate rows 20
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
## Write your code here
abs# Find duplicates based on specific columns
subset_duplicates = df[df.duplicated(subset=["MainBranch", "Employment", "RemoteWork"], keep=False)]

# Display first few of these duplicates
print(subset_duplicates.head())

print("Number of duplicate rows based on subset of columns:", subset_duplicates.shape[0])

# Group by the subset columns and count unique values in other columns
duplicate_analysis = subset_duplicates.groupby(["MainBranch", "Employment", "RemoteWork"]).agg(lambda x: x.nunique())

# Show columns that often have the same values (i.e., low number of unique entries)
print(duplicate_analysis.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
## Write your code here

# Get full duplicate rows
duplicates = df[df.duplicated(keep=False)]
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# Count duplicates by Country
country_counts = duplicates["Country"].value_counts().head(10)  # Top 10

# Bar plot
plt.figure(figsize=(10, 6))
plt.barh(country_counts.index, country_counts.values, color="skyblue")
plt.xlabel("Number of Duplicates")
plt.title("Top 10 Countries with Duplicate Rows")
plt.gca().invert_yaxis()  # Highest value at the top
plt.tight_layout()
plt.show()

# Count duplicates by Employment
employment_counts = duplicates["Employment"].value_counts()

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(employment_counts, labels=employment_counts.index, autopct="%1.1f%%", startangle=140)
plt.title("Distribution of Duplicates by Employment")
plt.axis("equal")
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
# Check duplicates based on a subset of columns
subset_cols = ["MainBranch", "Employment", "Country", "Age"]
duplicates_subset = df[df.duplicated(subset=subset_cols, keep=False)]

print("Number of duplicates based on subset:", duplicates_subset.shape[0])

# Remove duplicates based on the subset of columns, keep the first occurrence
df_cleaned = df.drop_duplicates(subset=subset_cols, keep='first')

print("Original dataset size:", df.shape)
print("Dataset size after removing duplicates:", df_cleaned.shape)
# Out:
# Number of duplicates based on subset: 60075
# Original dataset size: (65457, 114)
# Dataset size after removing duplicates: (9243, 114)

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# Objective:
# To ensure data quality and integrity by identifying and removing duplicate records that could skew analysis results.
#
# Steps Taken:
#
# Identification of duplicates:
#
# Initially, duplicate rows were identified across the entire dataset using df.duplicated() to count exact row duplicates.
#
# Further analysis was done by focusing on duplicates based on critical columns (MainBranch, Employment, Country, and Age) to detect duplicates that might not be exact but represent the same entity or response.
#
# Analysis of duplicates:
#
# Explored the characteristics of duplicates based on the subset of critical columns.
#
# Assessed which other columns tend to have identical values within duplicate groups to understand the nature of duplication.
#
# Strategic removal:
#
# Removed duplicates using drop_duplicates() based on the selected subset of columns that define uniqueness.
#
# Kept the first occurrence of each duplicated record to retain valid data points without redundancy.
#
# Verification:
#
# Confirmed removal by comparing dataset size before and after the cleaning process.
#
# Verified no unintended data loss occurred beyond duplicates.
#
# Outcome:
# This approach improved dataset reliability by eliminating redundant records while preserving unique information essential for accurate analysis.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# When cleaning data, defining what makes a record unique is crucial. Not all columns carry equal weight in identifying duplicates, so choosing the right subset ensures meaningful and accurate deduplication.
#
# Relevance to Uniqueness:
# Columns like "MainBranch", "Employment", "Country", and "Age" were chosen because they represent fundamental attributes that collectively describe each survey participant’s key profile. These fields are less likely to change or be entered differently across duplicate entries.
#
# Avoiding Noise from Non-Critical Columns:
# Other columns, such as comments, timestamps, or optional responses, may vary even for the same respondent or contain missing/noisy data. Using the entire row for duplication checks could mistakenly miss duplicates due to small differences in these fields.
#
# Balancing Precision and Recall:
# Selecting a meaningful subset balances removing true duplicates (high precision) without accidentally deleting unique but slightly different records (high recall). This subset was chosen to reflect core participant identity and work context, which likely remains consistent across duplicates.
#
# Improving Data Quality:
# Focusing on these columns helps clean redundant entries that would otherwise skew aggregate statistics or analyses, leading to more reliable insights without losing valuable information.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
